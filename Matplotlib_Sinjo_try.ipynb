# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(0,10,10)

# %%
y = x**2

# %%
plt.plot(x,y)
plt.xlabel('Numbers')
plt.ylabel('Squres')
plt.title('Squres of Numbers')
plt.show()

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,.8,.9])
axes1.set_title('Bigger Graph')
axes2 = fig.add_axes([0.2,.5,.3,.4])
axes2.set_title('Smaller Graph')
axes1.plot(x,y,'r')
axes2.plot(y,x)

# %%
fig,axes = plt.subplots(nrows = 1, ncols = 2)
axes[0].plot(x,y,'r')
axes[1].plot(y,x,'g')
axes[0].set_title('First Plot')
axes[1].set_title('Second Plot')
plt.tight_layout()

# %%
fig = plt.figure(figsize = (3,2), dpi = 100)
ax = fig.add_axes([.1,.1,.8,.8])
plt.plot(x,y)
ax.set_title('X vs. Y Plot')
ax.set_xlabel('X -->')
ax.set_ylabel('Y -->')
# Out:
# Text(0, 0.5, 'Y -->')

# %%
fig,axes = plt.subplots(nrows = 2, ncols = 1,figsize = (5,3), dpi = 200)
axes[0].plot(x,x**2,'b--', label= 'X squred', marker = '+')
axes[1].plot(x,x**3, color = 'Red', label='X cubed', marker = 'o')
fig.legend(loc = (.75,.65))
plt.tight_layout()

# %%
fig.savefig('my_plot.png')

# %%
fig1 = plt.figure()
ax = fig1.add_axes([0.1,0.1,0.9,0.9])
ax.plot(x,x**2,color ='Blue', marker = '+',label = 'Squred Plot')
ax.plot(x,x**3, color = 'Red', marker = 'o', label = 'Cubic Plot')
fig1.legend(loc = (.2,.7))

# %%
fig1,ax1 = plt.subplots(1,3,figsize = (12,4))
ax1[0].plot(x,x+2,x,x+5)
ax1[0].set_title('Sumed by 2 & 5')
ax1[1].plot(x,x**0.5,x,x**2)
ax1[1].set_title('Exp of half & two')
ax1[2].plot(x,x**2,x,x**3)
ax1[2].set_title('Exp of two & three')
# Out:
# Text(0.5, 1.0, 'Exp of two & three')

# %% [markdown]
# # Scatter Plot & Histogram

# %%
plt.scatter(x,y)

# %%
from random import sample 
data = sample(range(1,1000), 100)
plt.hist(data)
# Out:
# (array([ 3., 13.,  8., 11., 10., 11.,  8.,  9.,  8., 19.]),
#  array([ 14. , 111.3, 208.6, 305.9, 403.2, 500.5, 597.8, 695.1, 792.4,
#         889.7, 987. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Rectangular Box plot

# %%
data = [np.random.normal(0,std,100) for std in range(1,4)]
plt.boxplot(data,vert = True, patch_artist = True);

# %% [markdown]
# # Recap of all above concepts

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %%
figu = plt.figure(figsize = (5,4), dpi = 100)
axi = figu.add_axes([.1,.1,.8,.8])
plt.plot(x,y)
axi.set_title('Title')
axi.set_xlabel('X')
axi.set_ylabel('Y');

# %%
figu = plt.figure()
ax1 = figu.add_axes([0,0,1,1])
ax2 = figu.add_axes([0.2,0.5,.2,.2])

# %%
figu = plt.figure()
ax1 = figu.add_axes([0,0,1,1])
ax1.plot(x,y)
ax2 = figu.add_axes([0.2,0.5,.2,.2])
ax2.plot(x,y)

# %%
figu = plt.figure()
ax1 = figu.add_axes([0,0,1,1])

ax2 = figu.add_axes([0.2,0.5,.4,.4])

# %%
figu = plt.figure()
ax1 = figu.add_axes([0,0,1,1])
ax1.plot(x,z)
ax1.set_xlabel('X')
ax1.set_ylabel('Z')

ax2 = figu.add_axes([0.2,0.5,.4,.4])
ax2.plot(x,y)
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_title('zoom')
# Out:
# Text(0.5, 1.0, 'zoom')

# %%
figu,ax = plt.subplots(nrows = 1, ncols = 2)

# %%
figu,ax = plt.subplots(nrows = 1, ncols = 2)
ax[0].plot(x,y,'b',ls = '--',lw = 3)
ax[1].plot(x,z,'r',lw = 3);
figu.tight_layout()

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 3))
ax[0].plot(x,y,'r',ls = '--',lw = 3)
ax[0].set_xlabel('X')
ax[0].set_ylabel('Y')
ax[1].plot(x,z,'b',lw = 3)
ax[1].set_xlabel('X')
ax[1].set_ylabel('Z')
figu.tight_layout();

# %% [markdown]
# # Advance Matplotlib topics

# %%
x = np.arange(0,5)#x = np.linspace(0,20,40)

# %%
fig,ax = plt.subplots(1,2,figsize = (10,4))
ax[0].plot(x,x**2, x, np.exp(x))
ax[0].set_title('Normal Scale')
ax[1].plot(x,x**2, x,np.exp(x))
ax[1].set_yscale('log')
ax[1].set_title('Logarithmic scale (y)')
# Out:
# Text(0.5, 1.0, 'Logarithmic scale (y)')

# %%
fig, ax = plt.subplots(figsize =(10,4))
ax.plot(x, x**2, x, x**3, lw = 2)
ax.set_xticks([1,2,3,4,5])
ax.set_xticklabels([r'$\alpha$',r'$\beta$',r'$\gamma$', r'$\delta$',r'$\epsilon$'])
yval = [0,25,50,75,100]
ax.set_yticks(yval)
ax.set_yticklabels(['$%.1f$'%y for y in yval], fontsize = 18);

# %%
fig, ax = plt.subplots(1,1)
ax.plot(x, x**2, x, np.exp(x))
ax.set_title('Scientific Notation')
ax.set_yticks([0,50,100,150])

from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText = True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
ax.yaxis.set_major_formatter(formatter)

# %% [markdown]
# Axis Number and Axis Labeling

# %%
import matplotlib as mpl

# %%
mpl.rcParams['xtick.major.pad'] = 5
mpl.rcParams['ytick.major.pad'] = 5

fig , ax = plt.subplots(1,1)
ax.plot(x ,x**2 , x , np.exp(x))
ax.set_yticks([0,20,40,60])
ax.set_title('Axis Number & Labeling')

ax.xaxis.labelpad = 5
ax.yaxis.labelpad = 5
ax.set_xlabel('X')
ax.set_ylabel('Y');

# %% [markdown]
# Giving Axis Grid

# %%
fig , ax = plt.subplots(1,2, figsize=(10,3))
ax[0].plot(x, x**2, x, x*10, lw = 2)
ax[0].grid(True)

ax[1].plot(x , x**2, x, x**3, lw = 2)
ax[1].grid(color = 'r', alpha = 0.5, ls = 'dashed', lw = 0.5)

# %% [markdown]
# Twin Axes

# %%
# plotting area of a squre and volume of cube in a twin axis graph

fig, ax1 = plt.subplots()
ax1.plot(x, x**2, lw = 2, color = 'blue')
ax1.set_ylabel(r'Area $(m^2)$', fontsize = 18, color ='blue')
for label in ax1.get_yticklabels():
    label.set_color('blue')

ax2 = ax1.twinx()
ax2.plot(x, x**3, lw = 2, color = 'red')
ax2.set_ylabel(r"volume $(m^3)$", fontsize=18, color="red")
ytl_obj = plt.getp(ax2, 'yticklabels') 
for label in ytl_obj:
    plt.setp(ytl_obj, color="r")

# %% [markdown]
# Axis where x and y are zero

# %%
fig , ax = plt.subplots()

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))

ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

xx = np.linspace(-0.75, 1., 100)
ax.plot(xx,xx**3);

# %% [markdown]
# Other 2D Plot Styles

# %%
n = np.array([0,1,2,3,4,5])

# %%
fig, ax = plt.subplots(1,4, figsize = (12,3))

ax[0].scatter(xx, xx + 0.25*np.random.randn(len(xx)))
ax[0].set_title('Scatter')

ax[1].step(n, n**2, lw = 2)
ax[1].set_title('Step')

ax[2].bar(n, n**2, align= 'center', width = 0.5, alpha = 0.5)
ax[2].set_title('Bar')

ax[3].fill_between(x, x**2, x**3, color = 'green', alpha = 0.5)
ax[3].set_title('Fill between');

# %% [markdown]
# Text Automation

# %%
fig, ax = plt.subplots()
ax.plot(xx,xx**2, xx, xx**3)

ax.text(0.3,0.5,r"$y = x^2$", fontsize = 20 , color = '#0A99B1')
ax.text(0.9,0.5,r"$y = x^3$", fontsize = 20 , color = 'orange');

# %%
import matplotlib.gridspec as gridspec

# %%
fig = plt.figure()

gs = gridspec.GridSpec(2, 3, height_ratios=[2,1], width_ratios=[1,2,1])
for g in gs:
    ax= fig.add_subplot(g)
    
fig.tight_layout()

# %%
fig, ax = plt.subplots()

ax.plot(xx,xx**2, xx,xx**3)
fig.tight_layout()

inset_ax = fig.add_axes([0.3,0.55,0.35,0.35])
inset_ax.plot(xx,xx**2, xx,xx**3)
inset_ax.set_title('Zoom Near Orgin')

inset_ax.set_xlim(-0.2,0.2)
inset_ax.set_ylim(-0.005,0.01)
inset_ax.set_yticks([0, 0.005,0.01])
inset_ax.set_xticks([-0.1, 0, 0.1]);

# %% [markdown]
# # Colormap and contour figures

# %%
alpha = 0.7
pi_ext = 2 * np.pi * 0.5

def flus_qubit_potential(phi_m, phi_p):
    return 2 + alpha - 2 * np.cos(phi_m)*np.cos(phi_p)- alpha * np.cos(pi_ext - 2*phi_p)

# %%
phi_m = np.linspace(0, 2*np.pi, 100)
phi_p = np.linspace(0, 2*np.pi, 100)
X,Y = np.meshgrid(phi_m, phi_p)
Z = flus_qubit_potential(X , Y).T

# %%
import matplotlib

# %%
fig , ax = plt.subplots()

p = ax.pcolor(X/(2 * np.pi), Y/(2* np.pi), Z , cmap=matplotlib.cm.RdBu, vmin = abs(Z).min(), vmax = abs(Z).max()) 
cb = fig.colorbar(p, ax=ax)

# %%
fig , ax = plt.subplots()

im = ax.imshow(Z,cmap = matplotlib.cm.RdBu, vmin = abs(Z).min(), vmax = abs(Z).max(), extent = [0,1,0,1])
cb = fig.colorbar(p, ax=ax)

# %% [markdown]
# contour

# %%
fig , ax = plt.subplots()
cnt = ax.contour(Z, cmap = matplotlib.cm.RdBu, vmin = abs(Z).min(), vmax = abs(Z).max(), extent = [0,1,0,1])

# %% [markdown]
# #3D figures

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
fig = plt.figure(figsize = (14,6))

ax = fig.add_subplot(1,2,1, projection= '3d')
p = ax.plot_surface(X,Y,Z, rstride=4, cstride=4, linewidth=0)

ax = fig.add_subplot(1,2,2, projection= '3d')
p = ax.plot_surface(X,Y,Z, rstride=1, cstride=1, cmap=matplotlib.cm.coolwarm, linewidth=0, antialiased =False)

# %%
fig = plt.figure(figsize = (8,6))
ax = fig.add_subplot(1,1,1, projection = '3d')
p = ax.plot_wireframe(X,Y,Z, rstride = 4, cstride = 4)

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(1,1,1, projection = '3d')

ax.plot_surface(X,Y,Z, rstride=4, cstride=4, alpha = 0.2)

cset = ax.contour(X,Y,Z, zdir='z', offset = -np.pi, cmap = matplotlib.cm.coolwarm)
cset = ax.contour(X,Y,Z, zdir='x', offset = -np.pi, cmap = matplotlib.cm.coolwarm)
cset = ax.contour(X,Y,Z, zdir='y', offset = 3*np.pi, cmap = matplotlib.cm.coolwarm)

ax.set_xlim3d(-np.pi, 2*np.pi)
ax.set_ylim3d(0, 3*np.pi)
ax.set_zlim3d(-np.pi, 2*np.pi)
# Out:
# (-3.141592653589793, 6.283185307179586)
